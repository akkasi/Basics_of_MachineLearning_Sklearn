# %%
import mglearn
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/akkasi/Documents/software/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/akkasi/Documents/software/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/akkasi/Documents/software/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/akkasi/Documents/software/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# ...

# %%
mglearn.plots.plot_tree_not_monotone()
# Out:
# Feature importances: [0. 1.]

# %%
from sklearn.datasets import  load_breast_cancer
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

cancer =load_breast_cancer()
x_train,x_test,y_train,y_test =train_test_split(cancer.data,cancer.target,stratify=cancer.target,random_state=42)

# %%
tree =DecisionTreeClassifier(random_state=0)
tree.fit(x_train,y_train)
print("Accuracy on the training subset: {:.3f}".format(tree.score(x_train,y_train)))
print("Accuracy on the tes subset: {:.3f}".format(tree.score(x_test,y_test)))
# Out:
# Accuracy on the training subset: 1.000
# Accuracy on the tes subset: 0.937

# %%
tree
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
tree1 = DecisionTreeClassifier(max_depth=4,random_state=0)
tree1.fit(x_train,y_train)
print("Accuracy on the training subset: {:.3f}".format(tree1.score(x_train,y_train)))
print("Accuracy on the tes subset: {:.3f}".format(tree1.score(x_test,y_test)))
# Out:
# Accuracy on the training subset: 0.988
# Accuracy on the tes subset: 0.951

# %%
import graphviz
from sklearn.tree import export_graphviz

export_graphviz(tree,out_file='cancertree.dot',class_names=['malignant','benign'],feature_names=cancer.feature_names,
               impurity=False,filled=True)

# %% [markdown]
# # dot cancertree.dot -Tpng -o cancertree.png

# %% [markdown]
# ![](cancertree.png)

# %%
print('feature importances: {}'.format(tree.feature_importances_))
type(tree.feature_importances_)
# Out:
# feature importances: [0.         0.00752597 0.         0.         0.00903116 0.
#  0.00752597 0.         0.         0.         0.00975731 0.04630969
#  0.         0.00238745 0.00231135 0.         0.         0.
#  0.         0.00668975 0.69546322 0.05383211 0.         0.01354675
#  0.         0.         0.01740312 0.11684357 0.01137258 0.        ]
# numpy.ndarray

# %%
import numpy as np

# %%
n_features = cancer.data.shape[1]
plt.bar(range(n_features),tree.feature_importances_,align='center')
plt.yticks(np.arange(n_features),cancer.feature_names)
plt.xlbel('Feature Importance')
plt.ylabel('Feature')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d35c0d88d1c3> in <module>()
#       1 n_features = cancer.data.shape[1]
#       2 plt.bar(range(n_features),tree.feature_importances_,align='center')
# ----> 3 plt.yticks(np.arange(n_feature),cancer.feature_names)
#       4 plt.xlbel('Feature Importance')
#       5 plt.ylabel('Feature')
#
# NameError: name 'n_feature' is not defined

# %% [markdown]
# ![](cancertree.dot)
